# %%
import os
import sys
from typing import Callable

this_module = sys.modules[__name__]

def get_input() -> list[str]:
    return get_lines_from_file('./input')

def get_test_input(idx) -> list[str]:
    if os.path.isfile(f'./test_input{idx}'):
        return get_lines_from_file(f'./test_input{idx}')
    else:
        return get_lines_from_file('./test_input')
    
def get_test_result(idx) -> int:
    return get_int_from_file(f'./test_result{idx}')

def get_solution_func(idx) -> Callable:
    return getattr(this_module, f'solution{idx}')

def get_lines_from_file(filepath) -> list[str]:
    with open(filepath) as f:
        return [line.strip('\n') for line in f.readlines()]

def get_str_from_file(filepath) -> str:
    with open(filepath) as f:
        return f.readline().strip('\n')

def get_int_from_file(filepath) -> int:
    with open(filepath) as f:
        return int(f.readline().strip())

def log_invocation(func):
    def logged_func(*args):
        res = func(*args)
        print(f'{func.__name__}({args}) -> {res}')
        return res
    return logged_func
    
def run_test(idx: int) -> bool:
    res = get_solution_func(idx)(get_test_input(idx))
    test_res = get_test_result(idx)
    
    if test_res == res:
        print(f'Your solution for part {idx} works!!! :) (on the test input, that is)')
        print(f'Let`s try it on the actual input now...')
        return True
    else:
        print(f'Your solution for part {idx} does not work yet. Keep going!')
        print(f'You`ve got {res}, but the correct test result is {test_res}')
        return False

def run_solution(idx: int):
    sol = get_solution_func(idx)(get_input())
    print(f'The solution for part {idx} is: {sol}')

def run():
    if run_test(1):
        run_solution(1)
        print('\nOn to part 2...\n')
        if run_test(2):
            run_solution(2)

# %%
import re
from itertools import cycle

def parse_network(input_lines: list[str]) -> dict[str,dict]:
    node_dict = dict()
    for line in input_lines:
        matches = re.findall(r'[A-Z0-9]+', line)
        node = {
            'name': matches[0],
            'left': matches[1],
            'right': matches[2]
        }
        node_dict[node['name']] = node
    return node_dict

def solution1(input: list[str]) -> int:
    instructions = input[0]
    nodes = parse_network(input[2:])

    current_node = nodes['AAA']
    step_counter = 0
    for instr in cycle(instructions):
        if current_node['name'] == 'ZZZ':
            print('Found ZZZ :)')
            break
        if instr == 'R':
            current_node = nodes[current_node['right']]
        elif instr == 'L':
            current_node = nodes[current_node['left']]
        step_counter += 1
    return step_counter

def is_start_node(node: dict[str,str]) -> bool:
    return node['name'].endswith('A')

def is_end_node(node: dict[str,str]) -> bool:
    return node['name'].endswith('Z')

def solution2(input: list[str]) -> int:
    instructions = input[0]
    nodes = parse_network(input[2:])
    print(nodes)

    current_nodes = list(filter(is_start_node, nodes.values()))
    print(current_nodes)
    step_counter = 0
    for instr in cycle(instructions):
        if all([is_end_node(n) for n in current_nodes]):
            break
        for idx, current_node in enumerate(current_nodes):
            if instr == 'R':
                current_nodes[idx] = nodes[current_node['right']]
            elif instr == 'L':
                current_nodes[idx] = nodes[current_node['left']]
        step_counter += 1
    return step_counter

run()
# Out:
# Found ZZZ :)
# Your solution for part 1 works!!! :) (on the test input, that is)
# Let`s try it on the actual input now...
# Found ZZZ :)
# The solution for part 1 is: 13939
#
# On to part 2...
#
# {'11A': {'name': '11A', 'left': '11B', 'right': 'XXX'}, '11B': {'name': '11B', 'left': 'XXX', 'right': '11Z'}, '11Z': {'name': '11Z', 'left': '11B', 'right': 'XXX'}, '22A': {'name': '22A', 'left': '22B', 'right': 'XXX'}, '22B': {'name': '22B', 'left': '22C', 'right': '22C'}, '22C': {'name': '22C', 'left': '22Z', 'right': '22Z'}, '22Z': {'name': '22Z', 'left': '22B', 'right': '22B'}, 'XXX': {'name': 'XXX', 'left': 'XXX', 'right': 'XXX'}}
# [{'name': '11A', 'left': '11B', 'right': 'XXX'}, {'name': '22A', 'left': '22B', 'right': 'XXX'}]
# Your solution for part 2 works!!! :) (on the test input, that is)
# Let`s try it on the actual input now...
# {'RHQ': {'name': 'RHQ', 'left': 'QNL', 'right': 'HDC'}, 'FVH': {'name': 'FVH', 'left': 'LMX', 'right': 'SDD'}, 'MCR': {'name': 'MCR', 'left': 'THP', 'right': 'XKJ'}, 'RFJ': {'name': 'RFJ', 'left': 'TVQ', 'right': 'HGJ'}, 'MLK': {'name': 'MLK', 'left': 'KKF', 'right': 'MMK'}, 'JDL': {'name': 'JDL', 'left': 'XXQ', 'right': 'BFT'}, 'KXN': {'name': 'KXN', 'left': 'HFS', 'right': 'XFM'}, 'NJP': {'name': 'NJP', 'left': 'MSB', 'right': 'PBD'}, 'KDR': {'name': 'KDR', 'left': 'VFC', 'right': 'SBM'}, 'RKR': {'name': 'RKR', 'left': 'MBK', 'right': 'RFS'}, 'RJB': {'name': 'RJB', 'left': 'PQK', 'right': 'FHB'}, 'XTL': {'name': 'XTL', 'left': 'LMG', 'right': 'LMF'}, 'QDD': {'name': 'QDD', 'left': 'KFF', 'right': 'JSD'}, 'CFP': {'name': 'CFP', 'left': 'VBK', 'right': 'XNS'}, 'BQX': {'name': 'BQX', 'left': 'FFP', 'right': 'SKX'}, 'NSJ': {'name': 'NSJ', 'left': 'HNC', 'right': 'MLQ'}, 'KQQ': {'name': 'KQQ', 'left': 'LTG', 'right': 'TNH'}, 'KVN': {'name': 'KVN', 'left': 'SSJ', 'right': 'LNK'}, 'QCT': {'name': 'QCT', 'left': 'FQQ', 'right': 'LLX'}, 'LBB': {'name': 'LBB', 'left': 'VMQ', 'right': 'THT'}, 'DPQ': {'name': 'DPQ', 'left': 'PGL', 'right': 'GTC'}, 'RTH': {'name': 'RTH', 'left': 'QNQ', 'right': 'CMS'}, 'QLS': {'name': 'QLS', 'left': 'NFV', 'right': 'FKX'}, 'FST': {'name': 'FST', 'left': 'DNQ', 'right': 'QJQ'}, 'MHX': {'name': 'MHX', 'left': 'LFT', 'right': 'JDL'}, 'JLF': {'name': 'JLF', 'left': 'CCF', 'right': 'JNJ'}, 'TQJ': {'name': 'TQJ', 'left': 'VVT', 'right': 'TBV'}, 'HSC': {'name': 'HSC', 'left': 'LKR', 'right': 'GTS'}, 'GHV': {'name': 'GHV', 'left': 'NFS', 'right': 'RNT'}, 'VBK': {'name': 'VBK', 'left': 'CPT', 'right': 'MBX'}, 'HVV': {'name': 'HVV', 'left': 'CFH', 'right': 'QGR'}, 'JMG': {'name': 'JMG', 'left': 'LXR', 'right': 'NHP'}, 'DDJ': {'name': 'DDJ', 'left': 'LNK', 'right': 'SSJ'}, 'NKV': {'name': 'NKV', 'left': 'HLG', 'right': 'TCT'}, 'QBG': {'name': 'QBG', 'left': 'FHB', 'right': 'PQK'}, 'FKH': {'name': 'FKH', 'left': 'DDS', 'right': 'JLK'}, 'TLF': {'name': 'TLF', 'left': 'VKH', 'right': 'QLQ'}, 'NTR': {'name': 'NTR', 'left': 'MLL', 'right': 'GKH'}, 'KFF': {'name': 'KFF', 'left': 'MDN', 'right': 'HCD'}, 'NPF': {'name': 'NPF', 'left': 'FCP', 'right': 'VLM'}, 'PKP': {'name': 'PKP', 'left': 'HXS', 'right': 'KGH'}, 'DVV': {'name': 'DVV', 'left': 'TDH', 'right': 'XKB'}, 'SNM': {'name': 'SNM', 'left': 'BJN', 'right': 'SGS'}, 'JVC': {'name': 'JVC', 'left': 'PKX', 'right': 'CGR'}, 'VLB': {'name': 'VLB', 'left': 'RDM', 'right': 'VBP'}, 'RQQ': {'name': 'RQQ', 'left': 'KQQ', 'right': 'HHB'}, 'SHH': {'name': 'SHH', 'left': 'RRP', 'right': 'CSQ'}, 'DPN': {'name': 'DPN', 'left': 'HLR', 'right': 'LCK'}, 'MCT': {'name': 'MCT', 'left': 'BQG', 'right': 'SMV'}, 'FNJ': {'name': 'FNJ', 'left': 'QML', 'right': 'TVP'}, 'RGK': {'name': 'RGK', 'left': 'CTF', 'right': 'KTS'}, 'HNC': {'name': 'HNC', 'left': 'VPX', 'right': 'PPR'}, 'JLG': {'name': 'JLG', 'left': 'THT', 'right': 'VMQ'}, 'RJJ': {'name': 'RJJ', 'left': 'PLT', 'right': 'TFH'}, 'VRK': {'name': 'VRK', 'left': 'CMS', 'right': 'QNQ'}, 'JGJ': {'name': 'JGJ', 'left': 'JLF', 'right': 'RFM'}, 'RMD': {'name': 'RMD', 'left': 'BVV', 'right': 'XTG'}, 'MBB': {'name': 'MBB', 'left': 'QTQ', 'right': 'MCH'}, 'KDN': {'name': 'KDN', 'left': 'LMF', 'right': 'LMG'}, 'SPR': {'name': 'SPR', 'left': 'KHB', 'right': 'BPG'}, 'TFN': {'name': 'TFN', 'left': 'CTT', 'right': 'JGH'}, 'LXR': {'name': 'LXR', 'left': 'VTV', 'right': 'GRD'}, 'MPX': {'name': 'MPX', 'left': 'LSD', 'right': 'RDD'}, 'SDN': {'name': 'SDN', 'left': 'FLL', 'right': 'XSG'}, 'RMR': {'name': 'RMR', 'left': 'TMB', 'right': 'NKV'}, 'FJM': {'name': 'FJM', 'left': 'STG', 'right': 'DLM'}, 'HKK': {'name': 'HKK', 'left': 'VPV', 'right': 'HFQ'}, 'GQG': {'name': 'GQG', 'left': 'JDL', 'right': 'LFT'}, 'SQM': {'name': 'SQM', 'left': 'CJM', 'right': 'HSN'}, 'BFM': {'name': 'BFM', 'left': 'LKX', 'right': 'LKX'}, 'KMH': {'name': 'KMH', 'left': 'NDL', 'right': 'GNG'}, 'THT': {'name': 'THT', 'left': 'DXV', 'right': 'PHQ'}, 'XHT': {'name': 'XHT', 'left': 'FXG', ' ...
# [{'name': 'DVA', 'left': 'DXR', 'right': 'JLB'}, {'name': 'JQA', 'left': 'CSK', 'right': 'SDR'}, {'name': 'PTA', 'left': 'SMQ', 'right': 'RMD'}, {'name': 'CRA', 'left': 'BPD', 'right': 'FKN'}, {'name': 'AAA', 'left': 'JDG', 'right': 'CNN'}, {'name': 'BGA', 'left': 'CCP', 'right': 'NQV'}]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/florian/workspaces/private/advent-of-code-2023/day_8/solution.ipynb Cell 2 line 5
#      <a href='vscode-notebook-cell:/home/florian/workspaces/private/advent-of-code-2023/day_8/solution.ipynb#W1sZmlsZQ%3D%3D?line=54'>55</a>         step_counter += 1
#      <a href='vscode-notebook-cell:/home/florian/workspaces/private/advent-of-code-2023/day_8/solution.ipynb#W1sZmlsZQ%3D%3D?line=55'>56</a>     return step_counter
# ---> <a href='vscode-notebook-cell:/home/florian/workspaces/private/advent-of-code-2023/day_8/solution.ipynb#W1sZmlsZQ%3D%3D?line=57'>58</a> run()
#
# /home/florian/workspaces/private/advent-of-code-2023/day_8/solution.ipynb Cell 2 line 6
#      <a href='vscode-notebook-cell:/home/florian/workspaces/private/advent-of-code-2023/day_8/solution.ipynb#W1sZmlsZQ%3D%3D?line=60'>61</a> print('\nOn to part 2...\n')
#      <a href='vscode-notebook-cell:/home/florian/workspaces/private/advent-of-code-2023/day_8/solution.ipynb#W1sZmlsZQ%3D%3D?line=61'>62</a> if run_test(2):
# ---> <a href='vscode-notebook-cell:/home/florian/workspaces/private/advent-of-code-2023/day_8/solution.ipynb#W1sZmlsZQ%3D%3D?line=62'>63</a>     run_solution(2)
#
# /home/florian/workspaces/private/advent-of-code-2023/day_8/solution.ipynb Cell 2 line 5
#      <a href='vscode-notebook-cell:/home/florian/workspaces/private/advent-of-code-2023/day_8/solution.ipynb#W1sZmlsZQ%3D%3D?line=53'>54</a> def run_solution(idx: int):
# ---> <a href='vscode-notebook-cell:/home/florian/workspaces/private/advent-of-code-2023/day_8/solution.ipynb#W1sZmlsZQ%3D%3D?line=54'>55</a>     sol = get_solution_func(idx)(get_input())
#      <a href='vscode-notebook-cell:/home/florian/workspaces/private/advent-of-code-2023/day_8/solution.ipynb#W1sZmlsZQ%3D%3D?line=55'>56</a>     print(f'The solution for part {idx} is: {sol}')
#
# /home/florian/workspaces/private/advent-of-code-2023/day_8/solution.ipynb Cell 2 line 4
#      <a href='vscode-notebook-cell:/home/florian/workspaces/private/advent-of-code-2023/day_8/solution.ipynb#W1sZmlsZQ%3D%3D?line=45'>46</a> step_counter = 0
#      <a href='vscode-notebook-cell:/home/florian/workspaces/private/advent-of-code-2023/day_8/solution.ipynb#W1sZmlsZQ%3D%3D?line=46'>47</a> for instr in cycle(instructions):
# ---> <a href='vscode-notebook-cell:/home/florian/workspaces/private/advent-of-code-2023/day_8/solution.ipynb#W1sZmlsZQ%3D%3D?line=47'>48</a>     if all([is_end_node(n) for n in current_nodes]):
#      <a href='vscode-notebook-cell:/home/florian/workspaces/private/advent-of-code-2023/day_8/solution.ipynb#W1sZmlsZQ%3D%3D?line=48'>49</a>         break
#      <a href='vscode-notebook-cell:/home/florian/workspaces/private/advent-of-code-2023/day_8/solution.ipynb#W1sZmlsZQ%3D%3D?line=49'>50</a>     for idx, current_node in enumerate(current_nodes):
#
# /home/florian/workspaces/private/advent-of-code-2023/day_8/solution.ipynb Cell 2 line 4
#      <a href='vscode-notebook-cell:/home/florian/workspaces/private/advent-of-code-2023/day_8/solution.ipynb#W1sZmlsZQ%3D%3D?line=45'>46</a> step_counter = 0
#      <a href='vscode-notebook-cell:/home/florian/workspaces/private/advent-of-code-2023/day_8/solution.ipynb#W1sZmlsZQ%3D%3D?line=46'>47</a> for instr in cycle(instructions):
# ---> <a href='vscode-notebook-cell:/home/florian/workspaces/private/advent-of-code-2023/day_8/solution.ipynb#W1sZmlsZQ%3D%3D?line=47'>48</a>     if all([is_end_node(n) for n in current_nodes]):
#      <a href='vscode-notebook-cell:/home/florian/workspaces/private/advent-of-code-2023/day_8/solution.ipynb#W1sZmlsZQ%3D%3D?line=48'>49</a>         break
#      <a href='vscode-notebook-cell:/home/florian/workspaces/private/advent-of-code-2023/day_8/solution.ipynb#W1sZmlsZQ%3D%3D?line=49'>50</a>     for idx, current_node in enumerate(current_nodes):
#
# KeyboardInterrupt:
